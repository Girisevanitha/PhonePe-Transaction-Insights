# %%
#Downloading and Extracting GitHub Repository ZIP Files:

import requests
import zipfile
import io
url = "https://github.com/PhonePe/pulse/archive/refs/heads/main.zip"
response = requests.get(url)
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_data:
    zip_data.extractall('phonepe')
print('done')
# Out:
# done

# %%
#Importing packages:
import os
import json
import pandas as pd

# %%
# Reading Data Set
# Aggreated - Transaction

first_path = 'C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/aggregated/transaction/country/india/state/'
agg_trans_list= os.listdir(first_path)

# %%
column1 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in agg_trans_list:
    curr_state = first_path + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_transaction = json.load(f)

# %%
ag_transaction
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'from': 1727740800000,
#   'to': 1735344000000,
#   'transactionData': [{'name': 'Merchant payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 655100809,
#       'amount': 389286175909.0}]},
#    {'name': 'Peer-to-peer payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 493217788,
#       'amount': 1361927136312.0}]},
#    {'name': 'Recharge & bill payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 76043195,
#       'amount': 57534056540.0}]},
#    {'name': 'Financial Services',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 2352084,
#       'amount': 847296537.0}]},
#    {'name': 'Others',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 421806,
#       'amount': 505364108.0}]}]},
#  'responseTimestamp': 1739974491270}

# %%
column1 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in agg_trans_list:
    curr_state = first_path + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_transaction = json.load(f)
                
                for i in ag_transaction["data"]["transactionData"]:
                    name=i["name"]
                    count=i["paymentInstruments"][0]["count"]
                    amount = i["paymentInstruments"][0]["amount"]
                    column1["Transaction_type"].append(name)
                    column1["Transaction_count"].append(count)
                    column1["Transaction_amount"].append(amount)
                    column1["states"].append(state)
                    column1["years"].append(year)
                    column1["Quarters"].append(int(file.strip(".json")))

# %%
ag_transaction = pd.DataFrame(column1)
ag_transaction["states"]=ag_transaction["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
ag_transaction["states"]=ag_transaction["states"].str.replace("-"," ")
ag_transaction["states"]=ag_transaction["states"].str.title()
ag_transaction["states"]=ag_transaction["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
ag_transaction["states"].unique()
ag_transaction
# Out:
#                  states years  Quarters          Transaction_type  \
# 0     Andaman & Nicobar  2018         1  Recharge & bill payments
# 1     Andaman & Nicobar  2018         1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018         1         Merchant payments
# 3     Andaman & Nicobar  2018         1        Financial Services
# 4     Andaman & Nicobar  2018         1                    Others
# ...                 ...   ...       ...                       ...
# 5029        West Bengal  2024         4         Merchant payments
# 5030        West Bengal  2024         4     Peer-to-peer payments
# 5031        West Bengal  2024         4  Recharge & bill payments
# 5032        West Bengal  2024         4        Financial Services
# 5033        West Bengal  2024         4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# ...

# %%
#Aggreated - insurance

second_path = 'C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/aggregated/insurance/country/india/state/'
agg_insur_list= os.listdir(second_path)

# %%
column2 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in agg_insur_list:
    curr_state = second_path + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_insurance = json.load(f)

# %%
ag_insurance
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'from': 1727740800000,
#   'to': 1735344000000,
#   'transactionData': [{'name': 'Insurance',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 91719,
#       'amount': 120602777.0}]}]},
#  'responseTimestamp': 1739974635383}

# %%
column2 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in agg_insur_list:
    curr_state = second_path + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_insurance = json.load(f)
                
                for i in ag_insurance["data"]["transactionData"]:
                    name=i["name"]
                    count=i["paymentInstruments"][0]["count"]
                    amount = i["paymentInstruments"][0]["amount"]
                    column2["Transaction_type"].append(name)
                    column2["Transaction_count"].append(count)
                    column2["Transaction_amount"].append(amount)
                    column2["states"].append(state)
                    column2["years"].append(year)
                    column2["Quarters"].append(int(file.strip(".json")))

# %%
ag_insurance=pd.DataFrame(column2)
ag_insurance["states"]=ag_insurance["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
ag_insurance["states"]=ag_insurance["states"].str.replace("-"," ")
ag_insurance["states"]=ag_insurance["states"].str.title()
ag_insurance["states"]=ag_insurance["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
ag_insurance["states"].unique()
ag_insurance
# Out:
#                 states years  Quarters Transaction_type  Transaction_count  \
# 0    Andaman & Nicobar  2020         2        Insurance                  6
# 1    Andaman & Nicobar  2020         3        Insurance                 41
# 2    Andaman & Nicobar  2020         4        Insurance                124
# 3    Andaman & Nicobar  2021         1        Insurance                225
# 4    Andaman & Nicobar  2021         2        Insurance                137
# ..                 ...   ...       ...              ...                ...
# 677        West Bengal  2023         4        Insurance              72712
# 678        West Bengal  2024         1        Insurance              79576
# 679        West Bengal  2024         2        Insurance              67048
# 680        West Bengal  2024         3        Insurance              77158
# 681        West Bengal  2024         4        Insurance              91719
#
#      Transaction_amount
# 0                1360.0
# ...

# %%
#Aggreated - user

third_path = 'C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/aggregated/user/country/india/state/'
agg_user_list= os.listdir(third_path)

# %%
column3 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in agg_user_list:
    curr_state = third_path + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_user = json.load(f)

# %%
ag_user
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'aggregated': {'registeredUsers': 34750181, 'appOpens': 1994940763},
#   'usersByDevice': None},
#  'responseTimestamp': 1739974566918}

# %%
column3 = {"states":[], "years":[],"Quarters":[], "brands":[], "Transaction_count":[], "percentage":[]}
for state in agg_user_list:
    curr_state = third_path + state + "/"
    agg_year_list = os.listdir(curr_state)
    
    for year in agg_year_list:
        curr_year = curr_state + year + "/"
        agg_file_list = os.listdir(curr_year)
        
        for file in agg_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                ag_user = json.load(f)
                try:
                    for i in ag_user["data"]["usersByDevice"]:
                        brand=i["brand"]
                        count=i["count"]
                        percentage = i["percentage"]
                        column3["brands"].append(brand)
                        column3["Transaction_count"].append(count)
                        column3["percentage"].append(percentage)
                        column3["states"].append(state)
                        column3["years"].append(year)
                        column3["Quarters"].append(int(file.strip(".json")))
                except:
                    pass

# %%
ag_user = pd.DataFrame(column3)
ag_user["states"]=ag_user["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
ag_user["states"]=ag_user["states"].str.replace("-"," ")
ag_user["states"]=ag_user["states"].str.title()
ag_user["states"]=ag_user["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
ag_user["states"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        "Dadra and Nagar Haveli and Daman and Diu'", 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
ag_user
# Out:
#                  states years  Quarters   brands  Transaction_count  \
# 0     Andaman & Nicobar  2018         1   Xiaomi               1665
# 1     Andaman & Nicobar  2018         1  Samsung               1445
# 2     Andaman & Nicobar  2018         1     Vivo                982
# 3     Andaman & Nicobar  2018         1     Oppo                501
# 4     Andaman & Nicobar  2018         1  OnePlus                332
# ...                 ...   ...       ...      ...                ...
# 6727        West Bengal  2022         1   Lenovo             330017
# 6728        West Bengal  2022         1  Infinix             284678
# 6729        West Bengal  2022         1     Asus             280347
# 6730        West Bengal  2022         1    Apple             277752
# 6731        West Bengal  2022         1   Others            2196334
#
#       percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# 3       0.074332
# 4       0.049258
# ...          ...
# 6727    0.015056
# ...

# %%
#map- insurance

fourth_path = 'C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/map/insurance/hover/country/india/state/'
map_insur_list= os.listdir(fourth_path)

# %%
column4 = {"states":[], "years":[],"Quarters":[], "districts":[], "Transaction_count":[], "Transaction_amount":[]}
for state in map_insur_list:
    curr_state = fourth_path + state + "/"
    map_year_list = os.listdir(curr_state)
    
    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)
        
        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_insurance = json.load(f)
                
                for i in mp_insurance["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount = i["metric"][0]["amount"]
                    column4["districts"].append(name)
                    column4["Transaction_count"].append(count)
                    column4["Transaction_amount"].append(amount)
                    column4["states"].append(state)
                    column4["years"].append(year)
                    column4["Quarters"].append(int(file.strip(".json")))

# %%
mp_insurance
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'south twenty four parganas district',
#     'metric': [{'type': 'TOTAL', 'count': 6659, 'amount': 7720038.0}]},
#    {'name': 'purba bardhaman district',
#     'metric': [{'type': 'TOTAL', 'count': 3595, 'amount': 4482879.0}]},
#    {'name': 'uttar dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 1730, 'amount': 2115117.0}]},
#    {'name': 'kalimpong district',
#     'metric': [{'type': 'TOTAL', 'count': 137, 'amount': 298205.0}]},
#    {'name': 'murshidabad district',
#     'metric': [{'type': 'TOTAL', 'count': 3214, 'amount': 3386355.0}]},
#    {'name': 'paschim medinipur district',
#     'metric': [{'type': 'TOTAL', 'count': 4155, 'amount': 5405054.0}]},
#    {'name': 'dakshin dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 818, 'amount': 948223.0}]},
#    {'name': 'jalpaiguri district',
#     'metric': [{'type': 'TOTAL', 'count': 1622, 'amount': 2307554.0}]},
# ...

# %%
mp_insurance=pd.DataFrame(column4)
mp_insurance["states"]=mp_insurance["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
mp_insurance["states"]=mp_insurance["states"].str.replace("-"," ")
mp_insurance["states"]=mp_insurance["states"].str.title()
mp_insurance["states"]=mp_insurance["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
mp_insurance["states"].unique()
mp_insurance
# Out:
#                   states years  Quarters                          districts  \
# 0      Andaman & Nicobar  2020         2             south andaman district
# 1      Andaman & Nicobar  2020         2                  nicobars district
# 2      Andaman & Nicobar  2020         3  north and middle andaman district
# 3      Andaman & Nicobar  2020         3             south andaman district
# 4      Andaman & Nicobar  2020         3                  nicobars district
# ...                  ...   ...       ...                                ...
# 13871        West Bengal  2024         4                alipurduar district
# 13872        West Bengal  2024         4         paschim bardhaman district
# 13873        West Bengal  2024         4                     nadia district
# 13874        West Bengal  2024         4                   birbhum district
# 13875        West Bengal  2024         4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %%
mp_insurance.columns
# Out:
# Index(['states', 'years', 'Quarters', 'districts', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
#map- transaction

fifth_path = 'C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/map/transaction/hover/country/india/state/'
map_trans_list= os.listdir(fifth_path)

# %%
column5 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in map_trans_list:
    curr_state = fifth_path + state + "/"
    map_year_list = os.listdir(curr_state)
    
    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)
        
        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_transaction = json.load(f)

# %%
mp_transaction
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'south twenty four parganas district',
#     'metric': [{'type': 'TOTAL',
#       'count': 76936211,
#       'amount': 118552623594.0}]},
#    {'name': 'purba bardhaman district',
#     'metric': [{'type': 'TOTAL', 'count': 43690070, 'amount': 70602865584.0}]},
#    {'name': 'uttar dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 37198721, 'amount': 61950132057.0}]},
#    {'name': 'kalimpong district',
#     'metric': [{'type': 'TOTAL', 'count': 1847818, 'amount': 2646924444.0}]},
#    {'name': 'murshidabad district',
#     'metric': [{'type': 'TOTAL',
#       'count': 88522023,
#       'amount': 156002264967.0}]},
#    {'name': 'paschim medinipur district',
#     'metric': [{'type': 'TOTAL', 'count': 58238212, 'amount': 84317739854.0}]},
#    {'name': 'dakshin dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 13106067, 'amount': 21452200306.0}]},
# ...

# %%
column5 = {"states":[], "years":[],"Quarters":[], "districts":[], "Transaction_count":[], "Transaction_amount":[]}
for state in map_trans_list:
    curr_state = fifth_path + state + "/"
    map_year_list = os.listdir(curr_state)
    
    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)
        
        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_transaction = json.load(f)
                
                for i in mp_transaction["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount = i["metric"][0]["amount"]
                    column5["districts"].append(name)
                    column5["Transaction_count"].append(count)
                    column5["Transaction_amount"].append(amount)
                    column5["states"].append(state)
                    column5["years"].append(year)
                    column5["Quarters"].append(int(file.strip(".json")))

# %%
mp_trans = pd.DataFrame(column5)
mp_trans=pd.DataFrame(column5)
mp_trans["states"]=mp_trans["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
mp_trans["states"]=mp_trans["states"].str.replace("-"," ")
mp_trans["states"]=mp_trans["states"].str.title()
mp_trans["states"]=mp_trans["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
mp_trans["states"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        "Dadra and Nagar Haveli and Daman and Diu'", 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
mp_trans
# Out:
#                   states years  Quarters                          districts  \
# 0      Andaman & Nicobar  2018         1  north and middle andaman district
# 1      Andaman & Nicobar  2018         1             south andaman district
# 2      Andaman & Nicobar  2018         1                  nicobars district
# 3      Andaman & Nicobar  2018         2  north and middle andaman district
# 4      Andaman & Nicobar  2018         2             south andaman district
# ...                  ...   ...       ...                                ...
# 20599        West Bengal  2024         4                alipurduar district
# 20600        West Bengal  2024         4         paschim bardhaman district
# 20601        West Bengal  2024         4                     nadia district
# 20602        West Bengal  2024         4                   birbhum district
# 20603        West Bengal  2024         4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %%
#map- user

sixth_path = 'C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/map/user/hover/country/india/state/'
map_user_list= os.listdir(sixth_path)

# %%
column6 = {"states":[], "years":[],"Quarters":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount":[]}
for state in map_user_list:
    curr_state = fifth_path + state + "/"
    map_year_list = os.listdir(curr_state)
    
    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)
        
        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_user = json.load(f)

# %%
mp_user
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'south twenty four parganas district',
#     'metric': [{'type': 'TOTAL',
#       'count': 76936211,
#       'amount': 118552623594.0}]},
#    {'name': 'purba bardhaman district',
#     'metric': [{'type': 'TOTAL', 'count': 43690070, 'amount': 70602865584.0}]},
#    {'name': 'uttar dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 37198721, 'amount': 61950132057.0}]},
#    {'name': 'kalimpong district',
#     'metric': [{'type': 'TOTAL', 'count': 1847818, 'amount': 2646924444.0}]},
#    {'name': 'murshidabad district',
#     'metric': [{'type': 'TOTAL',
#       'count': 88522023,
#       'amount': 156002264967.0}]},
#    {'name': 'paschim medinipur district',
#     'metric': [{'type': 'TOTAL', 'count': 58238212, 'amount': 84317739854.0}]},
#    {'name': 'dakshin dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 13106067, 'amount': 21452200306.0}]},
# ...

# %%
column6 = {"states": [], "years": [], "Quarters": [], "districts": [], "RegisteredUsers": [], "AppOpens": []}

for state in map_user_list:
    curr_state = sixth_path + state + "/"
    map_year_list = os.listdir(curr_state)

    for year in map_year_list:
        curr_year = curr_state + year + "/"
        map_file_list = os.listdir(curr_year)

        for file in map_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                mp_user = json.load(f)
                for i in mp_user["data"]["hoverData"].items():
                     district=i[0]
                     registeredUsers=i[1]["registeredUsers"]
                     appOpens = i[1]["appOpens"]
                     column6["districts"].append(district)
                     column6["RegisteredUsers"].append(registeredUsers)
                     column6["AppOpens"].append(appOpens)
                     column6["states"].append(state)
                     column6["years"].append(year)
                     column6["Quarters"].append(int(file.strip(".json")))

# %%
mp_user = pd.DataFrame(column6)
mp_user["states"]=mp_user["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
mp_user["states"]=mp_user["states"].str.replace("-"," ")
mp_user["states"]=mp_user["states"].str.title()
mp_user["states"]=mp_user["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
mp_user["states"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        "Dadra and Nagar Haveli and Daman and Diu'", 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
mp_user
# Out:
#                   states years  Quarters                          districts  \
# 0      Andaman & Nicobar  2018         1  north and middle andaman district
# 1      Andaman & Nicobar  2018         1             south andaman district
# 2      Andaman & Nicobar  2018         1                  nicobars district
# 3      Andaman & Nicobar  2018         2  north and middle andaman district
# 4      Andaman & Nicobar  2018         2             south andaman district
# ...                  ...   ...       ...                                ...
# 20603        West Bengal  2024         4                alipurduar district
# 20604        West Bengal  2024         4         paschim bardhaman district
# 20605        West Bengal  2024         4                     nadia district
# 20606        West Bengal  2024         4                   birbhum district
# 20607        West Bengal  2024         4           purba medinipur district
#
#        RegisteredUsers   AppOpens
# ...

# %%
#top-insurance

seventh_path = 'C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/top/insurance/country/india/state/'
top_insur_list= os.listdir(seventh_path)

# %%
column7 = {"states": [], "years": [], "Quarters": [], "Pincodes": [], "Transaction_count": [], "Transaction_amount": []}

for state in top_insur_list:
    curr_state = seventh_path + state + "/"
    top_year_list = os.listdir(curr_state)

    for year in top_year_list:
        curr_year = curr_state + year + "/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                top_ins = json.load(f)
                for i in top_ins["data"]["pincodes"]:
                     entityname=i["entityName"]
                     count=i["metric"]["count"]
                     amount = i["metric"]["amount"]
                     column7["Pincodes"].append(entityname)
                     column7["Transaction_count"].append(count)
                     column7["Transaction_amount"].append(amount)
                     column7["states"].append(state)
                     column7["years"].append(year)
                     column7["Quarters"].append(int(file.strip(".json")))

# %%
top_insurance=pd.DataFrame(column7)
top_insurance["states"]=top_insurance["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
top_insurance["states"]=top_insurance["states"].str.replace("-"," ")
top_insurance["states"]=top_insurance["states"].str.title()
top_insurance["states"]=top_insurance["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
top_insurance["states"].unique()
top_insurance
# Out:
#                  states years  Quarters Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2020         2   744301                  3
# 1     Andaman & Nicobar  2020         2   744104                  2
# 2     Andaman & Nicobar  2020         2   744101                  1
# 3     Andaman & Nicobar  2020         3   744112                  9
# 4     Andaman & Nicobar  2020         3   744105                  7
# ...                 ...   ...       ...      ...                ...
# 6663        West Bengal  2024         4   711101                713
# 6664        West Bengal  2024         4   700091                642
# 6665        West Bengal  2024         4   700150                627
# 6666        West Bengal  2024         4   700039                619
# 6667        West Bengal  2024         4   700156                574
#
#       Transaction_amount
# 0                  565.0
# 1                  513.0
# 2                  282.0
# 3                 3432.0
# ...

# %%
#top-transaction

eight_path="C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/top/transaction/country/india/state/"
top_trans_list=os.listdir(eight_path)

# %%
column8 = {"states": [], "years": [], "Quarters": [], "Pincodes": [], "Transaction_count": [], "Transaction_amount": []}

for state in top_trans_list:
    curr_state = eight_path + state + "/"
    top_year_list = os.listdir(curr_state)

    for year in top_year_list:
        curr_year = curr_state + year + "/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                top_trans = json.load(f)
                for i in top_trans["data"]["pincodes"]:
                     entityname=i["entityName"]
                     count=i["metric"]["count"]
                     amount = i["metric"]["amount"]
                     column8["Pincodes"].append(entityname)
                     column8["Transaction_count"].append(count)
                     column8["Transaction_amount"].append(amount)
                     column8["states"].append(state)
                     column8["years"].append(year)
                     column8["Quarters"].append(int(file.strip(".json")))

# %%
top_trans = pd.DataFrame(column8)
top_trans["states"]=top_trans["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
top_trans["states"]=top_trans["states"].str.replace("-"," ")
top_trans["states"]=top_trans["states"].str.title()
top_trans["states"]=top_trans["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
top_trans["states"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        "Dadra and Nagar Haveli and Daman and Diu'", 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
top_trans
# Out:
#                  states years  Quarters Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2018         1   744101               1622
# 1     Andaman & Nicobar  2018         1   744103               1223
# 2     Andaman & Nicobar  2018         1   744102                969
# 3     Andaman & Nicobar  2018         1   744105                685
# 4     Andaman & Nicobar  2018         1   744104                340
# ...                 ...   ...       ...      ...                ...
# 9994        West Bengal  2024         4   711101            6753348
# 9995        West Bengal  2024         4   700059            6662715
# 9996        West Bengal  2024         4   700039            6575693
# 9997        West Bengal  2024         4   734001            6432082
# 9998        West Bengal  2024         4   733134            6313560
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# ...

# %%
# top -user
ninth_path="C:/Users/Prakash/Desktop/MDT48/phonepe/pulse-master/data/top/user/country/india/state/"
top_user_list=os.listdir(ninth_path)

# %%
column9 = {"states": [], "years": [], "Quarters": [], "Pincodes": [], "RegisteredUsers": []}

for state in top_user_list:
    curr_state = ninth_path + state + "/"
    top_year_list = os.listdir(curr_state)

    for year in top_year_list:
        curr_year = curr_state + year + "/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year + file
            with open(curr_file, "r") as f:
                top_user = json.load(f)
                for i in top_user["data"]["pincodes"]:
                     name=i["name"]
                     registeredusers=i["registeredUsers"]
                     column9["Pincodes"].append(name)
                     column9["RegisteredUsers"].append(registeredusers)
                     column9["states"].append(state)
                     column9["years"].append(year)
                     column9["Quarters"].append(int(file.strip(".json")))

# %%
top_users = pd.DataFrame(column9)
top_users["states"]=top_users["states"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
top_users["states"]=top_users["states"].str.replace("-"," ")
top_users["states"]=top_users["states"].str.title()
top_users["states"]=top_users["states"].str.replace("Dadra & Nagar Haveli & Daman & Diu","Dadra and Nagar Haveli and Daman and Diu'")
top_users["states"].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        "Dadra and Nagar Haveli and Daman and Diu'", 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
top_users
# Out:
#                  states years  Quarters Pincodes  RegisteredUsers
# 0     Andaman & Nicobar  2018         1   744103             1608
# 1     Andaman & Nicobar  2018         1   744101             1108
# 2     Andaman & Nicobar  2018         1   744105             1075
# 3     Andaman & Nicobar  2018         1   744102             1006
# 4     Andaman & Nicobar  2018         1   744104              272
# ...                 ...   ...       ...      ...              ...
# 9995        West Bengal  2024         4   733134           169596
# 9996        West Bengal  2024         4   700059           169448
# 9997        West Bengal  2024         4   711302           146034
# 9998        West Bengal  2024         4   700150           142151
# 9999        West Bengal  2024         4   711106           142077
#
# [10000 rows x 5 columns]

# %%
# importing packages for connecting mysql:

# !pip install mysql-connector-python

# %%
import mysql.connector as db

# %%
user='girisevanitha'
host='localhost'
passcode='Evanitha0805@'
db_name='project_phonepe'

# %%
db_connection=db.connect(
    user=user,
    host=host,
    password=passcode,
    database=db_name
)

# %%
db_connection

# %%
curr=db_connection.cursor()

# %%
ag_insurance.columns
# Out:
# Index(['states', 'years', 'Quarters', 'Transaction_type', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
# creating tables:

curr.execute("""
CREATE TABLE IF NOT EXISTS ag_insurance (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Transaction_type Varchar(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
first_table=""" INSERT INTO project_phonepe.ag_insurance(States,Years,Quarter,Transaction_type,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
T1= ag_insurance.values.tolist()
curr.executemany(first_table,T1)
db_connection.commit()

# %%
ag_transaction.columns
# Out:
# Index(['states', 'years', 'Quarters', 'Transaction_type', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS ag_transaction (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Transaction_type Varchar(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
second_table=""" INSERT INTO project_phonepe.ag_transaction(States,Years,Quarter,Transaction_type,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
T2=ag_transaction.values.tolist()
curr.executemany(second_table,T2)
db_connection.commit()

# %%
ag_user.columns
# Out:
# Index(['states', 'years', 'Quarters', 'brands', 'Transaction_count',
#        'percentage'],
#       dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS ag_user (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Brands VARCHAR(255),
        Transaction_count BIGINT,
        Percentage FLOAT
    
);
""")
db_connection.commit()

# %%
third_table=""" INSERT INTO project_phonepe.ag_user(States,Years,Quarter,Brands,Transaction_count,Percentage)
         values(%s,%s,%s,%s,%s,%s)"""
T3=ag_user.values.tolist()
curr.executemany(third_table,T3)
db_connection.commit()

# %%
mp_insurance.columns
# Out:
# Index(['states', 'years', 'Quarters', 'districts', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS mp_insurance (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        District VARCHAR(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
fourth_table=""" INSERT INTO project_phonepe.mp_insurance(States,Years,Quarter,District,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
T4=mp_insurance.values.tolist()
curr.executemany(fourth_table,T4)
db_connection.commit()

# %%
mp_trans.columns
# Out:
# Index(['states', 'years', 'Quarters', 'districts', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS mp_trans (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        District VARCHAR(255),
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
fifth_table=""" INSERT INTO project_phonepe.mp_trans(States,Years,Quarter,District,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
T5=mp_trans.values.tolist()
curr.executemany(fifth_table,T5)
db_connection.commit()

# %%
mp_user.columns
# Out:
# Index(['states', 'years', 'Quarters', 'districts', 'RegisteredUsers',
#        'AppOpens'],
#       dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS mp_user (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        District VARCHAR(255),
        Registeredusers BIGINT,
        AppOpens BIGINT
    
);
""")
db_connection.commit()

# %%
sixth_table=""" INSERT INTO project_phonepe.mp_user(States,Years,Quarter,District,Registeredusers,AppOpens)
         values(%s,%s,%s,%s,%s,%s)"""
T6=mp_user.values.tolist()
curr.executemany(sixth_table,T6)
db_connection.commit()

# %%
top_insurance.columns
# Out:
# Index(['states', 'years', 'Quarters', 'Pincodes', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS top_insurance (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Pincodes BIGINT,
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
seventh_table=""" INSERT INTO project_phonepe.top_insurance(States,Years,Quarter,Pincodes,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
T7=top_insurance.values.tolist()
curr.executemany(seventh_table,T7)
db_connection.commit()

# %%
top_trans.columns
# Out:
# Index(['states', 'years', 'Quarters', 'Pincodes', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS top_trans (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Pincodes BIGINT,
        Transaction_count BIGINT,
        Transaction_amount BIGINT
    
);
""")
db_connection.commit()

# %%
eighth_table=""" INSERT INTO project_phonepe.top_trans(States,Years,Quarter,Pincodes,Transaction_count,Transaction_amount)
         values(%s,%s,%s,%s,%s,%s)"""
T8=top_trans.values.tolist()
curr.executemany(eighth_table,T8)
db_connection.commit()

# %%
top_users.columns
# Out:
# Index(['states', 'years', 'Quarters', 'Pincodes', 'RegisteredUsers'], dtype='object')

# %%
curr.execute("""
CREATE TABLE IF NOT EXISTS top_users (
        States VARCHAR(255),
        Years INT,
        Quarter INT,
        Pincodes BIGINT,
        Registeredusers BIGINT
    
);
""")
db_connection.commit()

# %%
ninth_table=""" INSERT INTO project_phonepe.top_users(States,Years,Quarter,Pincodes,Registeredusers)
         values(%s,%s,%s,%s,%s)"""
T9=top_users.values.tolist()
curr.executemany(ninth_table,T9)
db_connection.commit()

# %%
user='girisevanitha'
host='localhost'
passcode='Evanitha0805@'
db_name='project_phonepe'

# %%
db_connection=db.connect(
    user=user,
    host=host,
    password=passcode,
    database=db_name
)

# %%
curr.execute("SELECT * FROM ag_insurance")
db_connection.commit()
Data1=curr.fetchall()
aggre_ins=pd.DataFrame(Data1,columns=("States","Years","Quarter","Transaction_type","Transaction_count","Transaction_amount"))

# %%
aggre_ins
# Out:
#                  States  Years  Quarter Transaction_type  Transaction_count  \
# 0     Andaman & Nicobar   2020        2        Insurance                  6
# 1     Andaman & Nicobar   2020        3        Insurance                 41
# 2     Andaman & Nicobar   2020        4        Insurance                124
# 3     Andaman & Nicobar   2021        1        Insurance                225
# 4     Andaman & Nicobar   2021        2        Insurance                137
# ...                 ...    ...      ...              ...                ...
# 2041        West Bengal   2023        4        Insurance              72712
# 2042        West Bengal   2024        1        Insurance              79576
# 2043        West Bengal   2024        2        Insurance              67048
# 2044        West Bengal   2024        3        Insurance              77158
# 2045        West Bengal   2024        4        Insurance              91719
#
#       Transaction_amount
# 0                   1360
# ...

# %%
curr.execute("SELECT * FROM ag_transaction")
db_connection.commit()
Data2=curr.fetchall()
aggre_trans=pd.DataFrame(Data2,columns=("States","Years","Quarter","Transaction_type","Transaction_count","Transaction_amount"))

# %%
aggre_trans
# Out:
#                   States  Years  Quarter          Transaction_type  \
# 0      Andaman & Nicobar   2018        1  Recharge & bill payments
# 1      Andaman & Nicobar   2018        1     Peer-to-peer payments
# 2      Andaman & Nicobar   2018        1         Merchant payments
# 3      Andaman & Nicobar   2018        1        Financial Services
# 4      Andaman & Nicobar   2018        1                    Others
# ...                  ...    ...      ...                       ...
# 15097        West Bengal   2024        4         Merchant payments
# 15098        West Bengal   2024        4     Peer-to-peer payments
# 15099        West Bengal   2024        4  Recharge & bill payments
# 15100        West Bengal   2024        4        Financial Services
# 15101        West Bengal   2024        4                    Others
#
#        Transaction_count  Transaction_amount
# 0                   4200             1845307
# 1                   1871            12138655
# ...

# %%
curr.execute("SELECT * FROM ag_user")
db_connection.commit()
Data3=curr.fetchall()
aggre_users=pd.DataFrame(Data3,columns=("States","Years","Quarter","Brands","Transaction_count","Percentage"))

# %%
aggre_users
# Out:
#                   States  Years  Quarter   Brands  Transaction_count  \
# 0      Andaman & Nicobar   2018        1   Xiaomi               1665
# 1      Andaman & Nicobar   2018        1  Samsung               1445
# 2      Andaman & Nicobar   2018        1     Vivo                982
# 3      Andaman & Nicobar   2018        1     Oppo                501
# 4      Andaman & Nicobar   2018        1  OnePlus                332
# ...                  ...    ...      ...      ...                ...
# 20191        West Bengal   2022        1   Lenovo             330017
# 20192        West Bengal   2022        1  Infinix             284678
# 20193        West Bengal   2022        1     Asus             280347
# 20194        West Bengal   2022        1    Apple             277752
# 20195        West Bengal   2022        1   Others            2196334
#
#        Percentage
# 0        0.247033
# 1        0.214392
# 2        0.145697
# 3        0.074332
# 4        0.049258
# ...           ...
# ...

# %%
curr.execute("SELECT * FROM mp_insurance")
db_connection.commit()
Data4=curr.fetchall()
map_ins=pd.DataFrame(Data4,columns=("States","Years","Quarter","District","Transaction_count","Transaction_amount"))

# %%
map_ins
# Out:
#                   States  Years  Quarter                           District  \
# 0      Andaman & Nicobar   2020        2             south andaman district
# 1      Andaman & Nicobar   2020        2                  nicobars district
# 2      Andaman & Nicobar   2020        3  north and middle andaman district
# 3      Andaman & Nicobar   2020        3             south andaman district
# 4      Andaman & Nicobar   2020        3                  nicobars district
# ...                  ...    ...      ...                                ...
# 41623        West Bengal   2024        4                alipurduar district
# 41624        West Bengal   2024        4         paschim bardhaman district
# 41625        West Bengal   2024        4                     nadia district
# 41626        West Bengal   2024        4                   birbhum district
# 41627        West Bengal   2024        4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %%
curr.execute("SELECT * FROM mp_trans")
db_connection.commit()
Data5=curr.fetchall()
map_trans=pd.DataFrame(Data5,columns=("States","Years","Quarter","District","Transaction_count","Transaction_amount"))

# %%
map_trans
# Out:
#                   States  Years  Quarter                           District  \
# 0      Andaman & Nicobar   2018        1  north and middle andaman district
# 1      Andaman & Nicobar   2018        1             south andaman district
# 2      Andaman & Nicobar   2018        1                  nicobars district
# 3      Andaman & Nicobar   2018        2  north and middle andaman district
# 4      Andaman & Nicobar   2018        2             south andaman district
# ...                  ...    ...      ...                                ...
# 61807        West Bengal   2024        4                alipurduar district
# 61808        West Bengal   2024        4         paschim bardhaman district
# 61809        West Bengal   2024        4                     nadia district
# 61810        West Bengal   2024        4                   birbhum district
# 61811        West Bengal   2024        4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %%
curr.execute("SELECT * FROM mp_user")
db_connection.commit()
Data6=curr.fetchall()
map_users=pd.DataFrame(Data6,columns=("States","Years","Quarter","District","Registeredusers","AppOpens"))

# %%
map_users
# Out:
#                   States  Years  Quarter                           District  \
# 0      Andaman & Nicobar   2018        1  north and middle andaman district
# 1      Andaman & Nicobar   2018        1             south andaman district
# 2      Andaman & Nicobar   2018        1                  nicobars district
# 3      Andaman & Nicobar   2018        2  north and middle andaman district
# 4      Andaman & Nicobar   2018        2             south andaman district
# ...                  ...    ...      ...                                ...
# 61819        West Bengal   2024        4                alipurduar district
# 61820        West Bengal   2024        4         paschim bardhaman district
# 61821        West Bengal   2024        4                     nadia district
# 61822        West Bengal   2024        4                   birbhum district
# 61823        West Bengal   2024        4           purba medinipur district
#
#        Registeredusers   AppOpens
# ...

# %%
curr.execute("SELECT * FROM top_insurance")
db_connection.commit()
Data7=curr.fetchall()
top_ins=pd.DataFrame(Data7,columns=("States","Years","Quarter","Pincodes","Transaction_count","Transaction_amount"))

# %%
top_ins
# Out:
#                   States  Years  Quarter  Pincodes  Transaction_count  \
# 0      Andaman & Nicobar   2020        2  744301.0                  3
# 1      Andaman & Nicobar   2020        2  744104.0                  2
# 2      Andaman & Nicobar   2020        2  744101.0                  1
# 3      Andaman & Nicobar   2020        3  744112.0                  9
# 4      Andaman & Nicobar   2020        3  744105.0                  7
# ...                  ...    ...      ...       ...                ...
# 19999        West Bengal   2024        4  711101.0                713
# 20000        West Bengal   2024        4  700091.0                642
# 20001        West Bengal   2024        4  700150.0                627
# 20002        West Bengal   2024        4  700039.0                619
# 20003        West Bengal   2024        4  700156.0                574
#
#        Transaction_amount
# 0                     565
# 1                     513
# 2                     282
# ...

# %%
curr.execute("SELECT * FROM top_trans")
db_connection.commit()
Data8=curr.fetchall()
top_trans=pd.DataFrame(Data8,columns=("States","Years","Quarter","Pincodes","Transaction_count","Transaction_amount"))

# %%
top_trans
# Out:
#                   States  Years  Quarter  Pincodes  Transaction_count  \
# 0      Andaman & Nicobar   2018        1  744101.0               1622
# 1      Andaman & Nicobar   2018        1  744103.0               1223
# 2      Andaman & Nicobar   2018        1  744102.0                969
# 3      Andaman & Nicobar   2018        1  744105.0                685
# 4      Andaman & Nicobar   2018        1  744104.0                340
# ...                  ...    ...      ...       ...                ...
# 29992        West Bengal   2024        4  711101.0            6753348
# 29993        West Bengal   2024        4  700059.0            6662715
# 29994        West Bengal   2024        4  700039.0            6575693
# 29995        West Bengal   2024        4  734001.0            6432082
# 29996        West Bengal   2024        4  733134.0            6313560
#
#        Transaction_amount
# 0                 2769298
# 1                 2238042
# 2                 3519060
# ...

# %%
curr.execute("SELECT * FROM top_users")
db_connection.commit()
Data9=curr.fetchall()
top_users=pd.DataFrame(Data9,columns=("States","Years","Quarter","Pincodes","Registeredusers"))

# %%
top_users
# Out:
#                   States  Years  Quarter  Pincodes  Registeredusers
# 0      Andaman & Nicobar   2018        1    744103             1608
# 1      Andaman & Nicobar   2018        1    744101             1108
# 2      Andaman & Nicobar   2018        1    744105             1075
# 3      Andaman & Nicobar   2018        1    744102             1006
# 4      Andaman & Nicobar   2018        1    744104              272
# ...                  ...    ...      ...       ...              ...
# 29995        West Bengal   2024        4    733134           169596
# 29996        West Bengal   2024        4    700059           169448
# 29997        West Bengal   2024        4    711302           146034
# 29998        West Bengal   2024        4    700150           142151
# 29999        West Bengal   2024        4    711106           142077
#
# [30000 rows x 5 columns]
